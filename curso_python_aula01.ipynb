# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorgenesSilva/-Python-em-2026-O-Guia-Definitivo-para-Inicio-do-Zero-/blob/main/curso_python_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **`## CURSO PYTHON INICIANTE`**

# %%
print('CURSO PYTHON INICIANTE')
# Out:
# CURSO PYTHON INICIANTE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Voltado para aqueles que buscam aprender sozinhos ou Autodidata**

# %% [markdown]
# ###### > O Estudante em Transição de Carreira
# ###### > O Profissional 30+ em Transição (Experiência + Tecnologia)
# ###### > O Buscador de Comodidade (Home Office e Flexibilidade)
# ###### > O Analista de Processos (Eficiência no Dia a Dia)
# ###### > Aspirantes a Desenvolvedores de Jogos e Apps
# ###### > O Analista de Dados e Planilhas (O "Mestre do Excel")
# ###### > O Profissional de Automação Residencial (Smart Home)

# %% [markdown]
# **...............................................................................**

# %% [markdown]
# **###    O que é a Linguagem Python ?    ###**
#
#
# #### Podemos Defenir o Python : #####
#
# ###### Python é uma **linguagem de programação** de **alto nível**, **orientada a objetos**, **funcional** e de **código aberto** **(open source)**, **Multiplataforma**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Obrigado Programador Iniciante ate a aula 2")
# Out:
# Obrigado Programador Iniciante ate a aula 2

# %% [markdown]
# CONTEUDO NO CANAL DO YOU TUBE :[https://www.youtube.com/@programadoriniciante-br](https://)

# %% [markdown]
# #https://www.python.org/#
