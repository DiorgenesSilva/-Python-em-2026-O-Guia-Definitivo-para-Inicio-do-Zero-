# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorgenesSilva/-Python-em-2026-O-Guia-Definitivo-para-Inicio-do-Zero-/blob/main/Curso_de_Python_aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***📽️ Aula 02: Seu Primeiro Script Python (Sem Instalar Nada!)***
#
# ###   Conteúdo do Curso Aula 02
#
# ##### **:> PASSO  01: Seu Primeiro Script Python**
# ##### **:> PASSO  02: Preparando o Ambiente**
# ##### **:> PASSO  03: O Primeiro Script: print()**
# ##### **:> PASSO  04: O Primeiro Erro (Aprendendo com a Prática)**
# ##### **:> PASSO  05: Mini-Projeto: Uma Calculadora Inteligente**
# ##### **:> PASSO  06: Desafio da Aula**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Celula de Codigo

# %% [markdown]
# Celula de Texto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###### Execute a Função Print() abaixo:

# %%
print("Olá, Programador iniciante !")
print("Estou começando minha jornada em 2026.")
# Out:
# Olá, Programador iniciante !
# Estou começando minha jornada em 2026.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('Olá Mundo !')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calcular quanto tempo voce ganha automatizando tarefas:
horas_por_dia = 2
dias_da_semana = 5
total_economizado = horas_por_dia * dias_da_semana

print("Se eu usar o Python para automatizar meu trabalho ...")
print('Eu vou economizar',  total_economizado, 'horas por semana')
# Out:
# Se eu usar o Python para automatizar meu trabalho ...
# Eu vou economizar 10 horas por semana

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ######OBS: O Programador Humilde, por Edsger W. Dijkstra
# ######_ Nós devemos fazer **um trabalho de programação melhor**, dado que nos aproximemos da tarefa com **total apreciação por sua tremenda dificuldade**, dado que nos seguremos a linguagens de programação **modestas e elegantes**, dado que nós **respeitemos** as **limitações intrínsecas** da **mente humana** e aproximemos da tarefa como **Programadores Muito Humildes**.

# %% [markdown]
# ### https://www.python.org/

# %% [markdown]
# ### **CURTA, COMENTE E COMPARTILHE**
