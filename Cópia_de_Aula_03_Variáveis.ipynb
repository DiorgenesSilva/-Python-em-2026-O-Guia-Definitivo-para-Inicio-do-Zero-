# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorgenesSilva/-Python-em-2026-O-Guia-Definitivo-para-Inicio-do-Zero-/blob/main/C%C3%B3pia_de_Aula_03_Vari%C3%A1veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "O Python entende:
# Guarda o texto '***' dentro da variável chamada usuario."

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [https://www.youtube.com/@programadoriniciante-br](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [https://github.com/DiorgenesSilva/-Python-em-2026-O-Guia-Definitivo-para-Inicio-do-Zero-](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [https://colab.research.google.com/](https://)

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# [https://www.python.org/](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
