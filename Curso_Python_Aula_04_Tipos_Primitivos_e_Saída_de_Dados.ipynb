# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorgenesSilva/-Python-em-2026-O-Guia-Definitivo-para-Inicio-do-Zero-/blob/main/Curso_Python_Aula_04_Tipos_Primitivos_e_Sa%C3%ADda_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Criando uma Variavel
moradia = 'casa'
comodos  = 5
valor= 20.500
vendido = False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nome = "Dimy"
idade = 18
altura = 1.70
aprovado = True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nome = 'Dimy'
idade = 18
altura = 1.70
aprovado = True

print(type(nome))
print(type(idade))
print(type(altura))
print(type(aprovado))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
